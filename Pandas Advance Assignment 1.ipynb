# %%
"""
Q1. List any five functions of the pandas library with execution.
"""

# %%
#Ans 1:
import pandas as pd

# %%
#Function 1:
#read_csv --> Helps to read csv file
df = pd.read_csv("services.csv")

# %%
#Function 2:
#head --> It returns the top entries of data frame
df.head()
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
#Function 3:
#tail --> It returns the last entries of data frame
df.tail()
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
#Function 4
#loc --> returns entry of dataframe based on names of indexes and columns
df.loc[ 0:3 , ['id','location_id'] ]
# Out:
#    id  location_id
# 0   1            1
# 1   2            2
# 2   3            3
# 3   4            4

# %%
#Function 5
#iloc --> returns entry of dataframe based on indexes of rows and columns
df.iloc[ 0:3 , 0:3 ]
# Out:
#    id  location_id  program_id
# 0   1            1         NaN
# 1   2            2         NaN
# 2   3            3         NaN

# %%
"""
Q2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the 
DataFrame with a new index that starts from 1 and increments by 2 for each row.
"""

# %%
#Ans2:
import pandas as pd

# %%
data = {
    'A': [10, 20, 30, 40],
    'B': [50, 60, 70, 80],
    'C': [90, 100, 110, 120]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     A   B    C
# 0  10  50   90
# 1  20  60  100
# 2  30  70  110
# 3  40  80  120

# %%
new_index = pd.RangeIndex(start=1, stop=len(df)*2, step=2,dtype = int)
df = df.reset_index(drop=True)
df = df.set_index(new_index)
df
# Out:
#     A   B    C
# 1  10  50   90
# 3  20  60  100
# 5  30  70  110
# 7  40  80  120

# %%
"""
Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that 
iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The 
function should print the sum to the console.

For example, if the 'Values' column of df contains the values [10, 20, 30, 40, 50], your function should 
calculate and print the sum of the first three values, which is 60.
"""

# %%
#Ans 3:
data_val = {
    'Values': [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data_val)

# %%
df
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
df['Values'][0]
# Out:
# 10

# %%
def sum_df(df):
    sum_final = 0
    for i in range(3):
        sum_final = sum_final+df['Values'][i]
    return sum_final

# %%
sum_df(df)
# Out:
# 60

# %%
"""
Q4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column 
'Word_Count' that contains the number of words in each row of the 'Text' column.
"""

# %%
#Ans 4:
data = {
    'Text': [
        "Lorem ipsum dolor sit amet",
        "Sed do eiusmod tempor incididunt",
        "Ut enim ad minim veniam, quis nostrud",
        "Duis aute irure",
    ]
}

df = pd.DataFrame(data)

# %%
df
# Out:
#                                     Text
# 0             Lorem ipsum dolor sit amet
# 1       Sed do eiusmod tempor incididunt
# 2  Ut enim ad minim veniam, quis nostrud
# 3                        Duis aute irure

# %%
len(df['Text'][0].split())
# Out:
# 5

# %%
df['word_count'] = df['Text'].apply(lambda x : len(x.split()))

# %%
df
# Out:
#                                     Text  word_count
# 0             Lorem ipsum dolor sit amet           5
# 1       Sed do eiusmod tempor incididunt           5
# 2  Ut enim ad minim veniam, quis nostrud           7
# 3                        Duis aute irure           3

# %%
def word_count(a):
    return len(a.split())

df['word_count'] = df['Text'].apply(word_count)
df
# Out:
#                                     Text  word_count
# 0             Lorem ipsum dolor sit amet           5
# 1       Sed do eiusmod tempor incididunt           5
# 2  Ut enim ad minim veniam, quis nostrud           7
# 3                        Duis aute irure           3

# %%
"""
Q5. How are DataFrame.size() and DataFrame.shape() different?
"""

# %%
"""
DataFrame.size() gives us the multiple of rows and columns that is the total elements present.
DataFrame.shape() gives us the structure of dataframe like (rows,columns).
"""

import pandas as pd

data = {
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
}

df = pd.DataFrame(data)

# DataFrame.size
print("DataFrame.size:", df.size) 

# DataFrame.shape
print("DataFrame.shape:", df.shape)
# Out:
# DataFrame.size: 9
# DataFrame.shape: (3, 3)

# %%
"""
Q6. Which function of pandas do we use to read an excel file?
"""

# %%
#Ans 6:
""" 
pd.read_excel() is used to read excel file in Pandas
"""

# %%
"""
Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email 
addresses in the format 'username@domain.com'. Write a Python function that creates a new column 
'Username' in df that contains only the username part of each email address.
"""

# %%
#Ans 7:
data = {
    'Email': [
        "sudh@gmail.com",
        "ronak@gmail.com",
        "krish@gmail.com",
        "hitesh@gmail.com",
    ]
}

df = pd.DataFrame(data)
df
# Out:
#               Email
# 0    sudh@gmail.com
# 1   ronak@gmail.com
# 2   krish@gmail.com
# 3  hitesh@gmail.com

# %%
df['Email'][0].split('@')
# Out:
# ['sudh', 'gmail.com']

# %%
df['Username'] = df['Email'].apply(lambda x : x.split('@')[0])

# %%
df
# Out:
#               Email Username
# 0    sudh@gmail.com     sudh
# 1   ronak@gmail.com    ronak
# 2   krish@gmail.com    krish
# 3  hitesh@gmail.com   hitesh

# %%
data = {
    'Email': [
        "sudh@gmail.com",
        "ronak@gmail.com",
        "krish@gmail.com",
        "hitesh@gmail.com",
    ]
}

df = pd.DataFrame(data)
df
# Out:
#               Email
# 0    sudh@gmail.com
# 1   ronak@gmail.com
# 2   krish@gmail.com
# 3  hitesh@gmail.com

# %%
def user_name(a):
    return a.split('@')[0]

df['Username'] = df['Email'].apply(user_name)
df
# Out:
#               Email Username
# 0    sudh@gmail.com     sudh
# 1   ronak@gmail.com    ronak
# 2   krish@gmail.com    krish
# 3  hitesh@gmail.com   hitesh

# %%
"""
Q8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects 
all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The 
function should return a new DataFrame that contains only the selected rows.
"""

# %%
#Ans 8:
data = {
    'A' : [3,8,6,2,9],
    'B' : [5,2,9,3,1],
    'C' : [1,7,4,5,2]
}

df = pd.DataFrame(data)
df
# Out:
#    A  B  C
# 0  3  5  1
# 1  8  2  7
# 2  6  9  4
# 3  2  3  5
# 4  9  1  2

# %%
def func(df):
    df1 = pd.DataFrame(columns = ['A','B','C'])
    for i in range(len(df)):
        if df['A'][i] > 5 and df['B'][i] < 10:
            df1 = df1.append(df.iloc[i])
    return df1

func(df)
# Out:
# /tmp/ipykernel_284/3254779804.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df.iloc[i])
# /tmp/ipykernel_284/3254779804.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df.iloc[i])
# /tmp/ipykernel_284/3254779804.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df.iloc[i])
#    A  B  C
# 1  8  2  7
# 2  6  9  4
# 4  9  1  2

# %%
"""
Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean, 
median, and standard deviation of the values in the 'Values' column.
"""

# %%
#Ans 9:
data_val = {
    'Values': [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data_val)
df
# Out:
#    Values
# 0      10
# 1      20
# 2      30
# 3      40
# 4      50

# %%
def calculate_statistics(df):
    mean_value = df['Values'].mean()
    median_value = df['Values'].median()
    std_value = df['Values'].std()
    
    return mean_value, median_value, std_value

mean_val, median_val, std_val = calculate_statistics(df)

print("Mean:", mean_val)
print("Median:", median_val)
print("Standard Deviation:", std_val)
# Out:
# Mean: 30.0
# Median: 30.0
# Standard Deviation: 15.811388300841896

# %%
"""
Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to 
create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days 
for each row in the DataFrame. The moving average should be calculated using a window of size 7 and 
should include the current day.
"""

# %%
#Ans 10:
import pandas as pd

def calculate_moving_average(df):
    # Sort the DataFrame by the 'Date' column (if not already sorted)
    df = df.sort_values('Date')
    df['MovingAverage'] = df['Sales'].rolling(window=7, min_periods=1).mean()
    return df

new_df = calculate_moving_average(df)

print(new_df)

# %%
"""
Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new 
column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g. 
Monday, Tuesday) corresponding to each date in the 'Date' column.
"""

# %%
#Ans 11:
import pandas as pd

# %%
l = pd.date_range(start = '2023-01-01', end = '2023-01-05')
l
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(pd.date_range(start = '2023-01-01', end = '2023-01-05'), columns=['Date'])
df
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05

# %%
def weekday_func(df):
    df['Weekday'] = df['Date'].dt.day_name()
    return df

# %%
df
# Out:
#         Date
# 0 2023-01-01
# 1 2023-01-02
# 2 2023-01-03
# 3 2023-01-04
# 4 2023-01-05

# %%
weekday_func(df)
# Out:
#         Date    Weekday
# 0 2023-01-01     Sunday
# 1 2023-01-02     Monday
# 2 2023-01-03    Tuesday
# 3 2023-01-04  Wednesday
# 4 2023-01-05   Thursday

# %%
"""
Q12.Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python 
function to select all rows where the date is between '2023-01-01' and '2023-01-31'.
"""

# %%
#Ans 12:
import pandas as pd

# %%
df = pd.DataFrame(pd.date_range(start = '2023-01-01', end = '2023-12-31'), columns=['Date'])

# %%
df
# Out:
#           Date
# 0   2023-01-01
# 1   2023-01-02
# 2   2023-01-03
# 3   2023-01-04
# 4   2023-01-05
# ..         ...
# 360 2023-12-27
# 361 2023-12-28
# 362 2023-12-29
# 363 2023-12-30
# 364 2023-12-31
#
# [365 rows x 1 columns]

# %%
def func_date(df):
    df1 = pd.DataFrame(columns = ['Date'])
    for i in range(len(df)):
        if str(df['Date'][i]) >= '2023-01-01' and str(df['Date'][i]) <= '2023-02-01':
            df1 = df1.append(df.iloc[i])
            
    return df1

func_date(df)
# Out:
# /tmp/ipykernel_85/729985744.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df.iloc[i])
# /tmp/ipykernel_85/729985744.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df.iloc[i])
# /tmp/ipykernel_85/729985744.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df.iloc[i])
# /tmp/ipykernel_85/729985744.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df1 = df1.append(df.iloc[i])
# /tmp/ipykernel_85/729985744.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
"""
Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to 
be imported?
"""

# %%
#Ans 13:
"""
The library which we need to import is pandas

code: import pandas as pd

"""
